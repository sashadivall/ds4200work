# %% [markdown]
# # DS4200 Homework 2
#
# Due: Friday Feb 7th @ 11:59 PM EST
#
# ### Submission Instructions
# Submit this `ipynb` file included with the coding results as well as the picture in the last question to Gradescope (this can also be done via the assignment on Canvas).  To ensure that your submitted files represent your latest code, make sure to give a fresh `Kernel > Restart & Run All` just before uploading the files to gradescope.
#
# ### Tips for success
# - Start early
# - Make use of Piazza
# - Make use of Office hour
# - Remember to use cells and headings to make the notebook easy to read (if a grader cannot find the answer to a problem, you will receive no points for it)
# - Under no circumstances may one student view or share their ungraded homework or quiz with another student [(see also)](http://www.northeastern.edu/osccr/academic-integrity), though you are welcome to **talk about** (not show each other) the problems.

# %% [markdown]
# ### Part 1 - Encodings (25 points)
#
# Navigate to [datavizproject](https://datavizproject.com/) and take some time to freely browse the website and explore. After browsing, find a visual encoding on the webpage that is new to you (i.e. one you have never seen before).
#
# ##### Quesiton 1 (5 pts)
# Put in this section a screenshot and hyperlink to the visual encoding that is new to you.

# %% [markdown]
# [Hive Plot](https://datavizproject.com/data-type/hive-plot/)
#
#
# **See hive_plot.png in zip file**

# %% [markdown]
# ##### Question 2 (5 pts)
#
# Add a short paragraph explaining what you like and do not like about the new-to-you visual encoding you selected.

# %% [markdown]
# As far as the visual aesthetics go, I like that each relationship (x/y, y/z, and x/z) has its own clear partition. This makes it easy to identify the relationships between two variables. I also like that it is clear that the width of the area within a partition represents some sort of quantitative value. For example, X and Z have a much higher value of whatever the blue area represents than X and Y. One thing I do not like about this visual encoding is that there is no numerical scale. This makes it difficult to identify the actual values represented by the thickness of the inner areas.

# %% [markdown]
# Take a look at the toolbar at the top of the webpage. Note how visualizations are organized (categorized) in multiple ways to help the user identify a visual encoding depending on whether they care about data type, composition, or task.
#
# ##### Question 3 (5 pts)
#
# What does “Input” mean? How are the visualizations categorized in this scheme? How does (if at all) this map to the language in our readings?

# %% [markdown]
# **Input** refers to how a set of data is structured. There are several categories of input, and while they are not labeled in the toolbar, the types can be inferred from the sample datasets. For example, there is time-series data, univariate data (one x and one y), multivariate data (one x maps to several attributes (y)), percentage/proportion data, range data, et cetera. The language from the textbook that most closely resembles this definition of input is data types and dataset types. Similar to input, data type and dataset type characterize the way the data is structured and the type of each data in the structure. For example, most of the input types on the datavizproject website are tables and most of the data types are items and attributes.

# %% [markdown]
# ##### Question 4 (5 pts)
#
# What does “Shape” mean? How are the visualizations categorized in this scheme? How does (if at all) this map to the language in our readings?

# %% [markdown]
# **Shape** refers to the shape of the data visualization produced from a given set of data. There is the square shape, which represents a traditional grid space, lines, circles, and even fun shapes like hearts and Texas. The language from the textbook that most closely resemble this definition of shape are marks and channels. Marks and channels are the ways in which we choose to represent our data visually to convey a particular message or trend. While less specific, the shape of a visualization helps in the delivering of such ideas.

# %% [markdown]
# ##### Question 5 (5 pts)
#
# What does “Function” mean? How are the visualizations categorized in this scheme? How does (if at all) this map to the language in our readings?

# %% [markdown]
# **Function** refers to the goal of the data visualization. For example, the `comparison` function category refers to visualizations that show the relationship between several variables. The language in the textbook that most closely resembles this definition of function is task. A task refers to the problem at hand that we attempt to solve or convey with a data visualization. For example, we can say that comparison is a task just as much as it is a function of a data visualization.

# %% [markdown]
# ### Part 2 - Xenographics (15 points)
#
# Watch the following talk about the Xenographics project by Maarten Lambrechts from the OpenVis Conf (2018): [https://www.youtube.com/watch?v=fp-WNqaQG0s](https://www.youtube.com/watch?v=fp-WNqaQG0s)
#
# Next, explore the online collection: https://xeno.graphics/.

# %% [markdown]
# Then, write a 1-2 paragraph response (minimum 200 words) which addresses the following questions:
#
# - What is the Xenographics project, and what is its goal?
# - How are the visualizations categorized and organized on the project website?
# - What was the most interesting or surprising thing you learned by watching the talk and exploring the website?
# - Provide a link and short description to your favorite visualization on the website.
#
# Your 1–2 paragraphs evidence a critical and thoughtful effort and answer the posed questions. Your writing shows a high degree of attention to logic and reasoning of points, is written in a clear manner, and words are chosen to precisely express the intended meaning and support reader comprehension. There are few English spelling or grammar mistakes.

# %% [markdown]
# The Xenographics project is an ever-growing collection of "weird" visualizations. The goal of the Xenographics project is to present and popularize unconventional techniques of data visualization. Maarten Lambrechts, the creator of the Xenographics project, places weird visualizations into five categories of weirdness, where a category 1 is the least weird of the xenographics, and a category 5 is the most weird. In order, the categories are: (1) flip axes, (2) break/stack scales, (3) crossbreed chart types, (4) add dimensions, and (5) crossbreed data types. On his website however, the data visualizations are categorized by function, like on the datavizproject website. Some of the categories of weirdness are closely related to the function categories, for example visualizations with the "scale stacking" tag can be said to have category 2 weirdness.
#
# Overall, Lambrechts' talk was very interesting and funny, but one of the most interesting topics of conversation was the resistance of data journalists to publish "strange" graphics. While I agree that it is important to popularize and publish innovative data visualization types, data journalists have a responsibility to convey the data to a non-academic audience (for the most part). With that being said, I can understand the pushback from data journalists regarding publishing complex data visualizations. With a simple data visualizations, the majority of the audience can clearly understand the trends in data without doing too much analysis into the scale of the x-axis or the relative height of stacked bars for example. My favorite visualization on the website is the [bracket probabilities chart](https://xeno.graphics/bracket-probabilities/). While it seems like there is a lot going on in this visualization, if you focus on a particular matchup, you can clearly see the probability of one of the teams winning throughout the match. This visualization could be useful for those who did not watch the match to get a sense of the score or intensity of the matchup throughout the game. Additionally, this sort of visualization can be used to predict future win probabilities between two teams.

# %% [markdown]
# ### Part 3 - Basic data analysis with Altair (40 points)
#
# We are going to use the same Weather data from Homework 1 but use Altair to create the data visualziation.
#
# ##### Question 1 (10 points)
#
# Recreate the figure in Part 3 Question 2 in Homework 1 with Altair. Include necessary title and labels. Here is the question again:
#
#     Generate a data visualization to show the relationship between max temperature and weather type.

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import altair as alt
from vega_datasets import data

weather = data.seattle_weather()
weather.head()
# Out:
#         date  precipitation  temp_max  temp_min  wind  weather
# 0 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2 2012-01-03            0.8      11.7       7.2   2.3     rain
# 3 2012-01-04           20.3      12.2       5.6   4.7     rain
# 4 2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
# Side-by-side boxplot
alt.Chart(weather).mark_boxplot().encode(
    alt.Y("temp_max:Q", title="Max Temperature"),
    alt.X("weather:N", title="Weather"),
    alt.Color("weather:N", legend=None)
).properties(
    title="Distribution of Maximum Temperatures by Weather Type"
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ##### Question 2 (10 points)
#
# Recreate the figure in Part 3 Question 3 in Homework 1 with Altair. Include necessary title and labels. Here is the question again:
#
#     Generate a data visualization to show the relationship between max temperature and min temperature, and then show different color for differnet weather type.

# %%
# Scatter plot
alt.Chart(weather).mark_circle().encode(
    alt.Y("temp_min:Q", title="Min Temperature"),
    alt.X("temp_max:Q", title="Max Temperature"),
    alt.Color("weather:N")
).properties(
    title="Max Temperature vs Min Temperature By Weather Type"
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ##### Question 3 (10 points)
#
# Create a facet figure in Altair with 2 row and 3 columns. For each panel in the facet figure, it shows a scatter plot between the max and min temperature for one type of weather. Use the wind speed to color the points. Also add interaction to show the max and min temperature and wind speed for each data point. Include necessary title and labels.

# %%
alt.Chart(weather).mark_circle().encode(
    alt.Y("temp_min:Q", title="Min Temperature"),
    alt.X("temp_max:Q", title="Max Temperature"),
    alt.Color("wind:Q", title="wind speed (mph)"),
    alt.Tooltip(["temp_max", "temp_min", "wind"])
).properties(
    title="Max Temperature vs Min Temperature by Weather",
    width = 120, height = 120
).facet(
    facet="weather:N",
    columns=3
)
# Out:
# alt.FacetChart(...)

# %% [markdown]
# ##### Question 4 (10 points)
#
# Create a compound figure with at least two types of marks. Show the trend of average temperature (the average of min and max temperature) in 4 years. Note, just use the `date` as X attribute, no need to aggragate for years and you will get a wide figure. Include necessary title and labels.

# %%
point = alt.Chart(weather).mark_circle(
    color="black", opacity=0.5
).transform_calculate(
    average_temp = '(datum.temp_min + datum.temp_max) / 2'
).encode(
    y = alt.Y("average_temp:Q", title="Average Temperature"),
    x = alt.X("date:T", title = "Date")
)
area = alt.Chart(weather).mark_area(
    color="blue", opacity=0.3, interpolate="monotone"
).transform_calculate(
    average_temp='(datum.temp_min + datum.temp_max) / 2'
).encode(
    alt.Y("average_temp:Q", title="Average Temperature"),
    alt.X("date:T", title="Date")
).properties(
    title="Trend of Average Temperature, 2012-2015"
)
point + area
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Part 4 - Colors (20 points)
#
# Please email the instructor if you have problems to complete the color-related homework.
#
# ##### Question 1 (5 points)
#
# Following is a density plot for the wind speed for all five types of weather. Is there any problems in the figure? Try to name at least two ways you can do to re-design the figure (change the mark/channel/encoding etc.)

# %% [markdown]
# <img src="https://i.ibb.co/QNfQ2tb/visualization.png" alt="visualization" border="0">

# %% [markdown]
# One problem with this figure is that the overlap of the density plots makes it difficult to see the density plots for the weather categories towards the back of the plot. For example, we can see the peak of the drizzle density plot, but the shape of the density plot on the left and right side is unclear. Similarly, it is very hard to see the density plot for rain since the peak does not rise above the others. Here are two ways to redesign the figure:
# 1. If the creator wants to stick with density plots, they should create five side-by-side faceted density plots where the scale is the same. This way, it is easy to see the entire density distribution for each weather type while still comparing density plots across weather categories.
# 2. Another option would be to use a stacked bar plot. For each wind category, a stacked bar could show the proportion of days where the weather was drizzle, fog, rain, snow, or sun.

# %% [markdown]
# ##### Question 2 （5 points）
#
# Go to [http://vrl.cs.brown.edu/color](http://vrl.cs.brown.edu/color) and select another color palette for the figure. Explain how to set the configuration to get the color palette. Take a screenshot of the color palette you have chosen on the website and then go to [https://www.color-blindness.com/coblis-color-blindness-simulator/](https://www.color-blindness.com/coblis-color-blindness-simulator/) and upload the screenshot. Discuss how one of the color-blind illness affects the figure.

# %% [markdown]
# To create a color palette with the Colorgorical website, you select a value for each of the following:
# - number of colors (for this experiment, the value is 5 because there are 5 different weather types)
# - perceptual distance: the relative difference in colors to the human eye (a higher value of perceptual distance will yield a palette with more distinct colors)
# - name difference: a measure of colors that share similar names (a higher value of name difference will yield a palette with less colors of the same base color, i.e, blues, greens)
# - pair preference: a measure of how aesthetically preferable certain colors are
# - name uniqueness: a measure of how unique a name is ("red" has a lower value of name uniqueness than "chartreuse" for example)
#
#
# My palette: **See my_palette.png in zip file**
#
# My settings: **See palette_settings.png in zip file**
#
# I chose the color-blind illness red-weak protanomaly to explore how my color palette can be perceived by a person with this illness. Here is what my color palette would look like to them:
#
# **See color_blindness.png**
#
# While all of the colors are slightly more muted, it is still easy to distinguish the colors from each other. If the hue of the color was a channel, it would be critical to provide a legend to ensure even those with color blindness can map the color to a particular category.

# %% [markdown]
# ##### Question 3 (10 points)
#
# Based on what we have learned in the lecture, try to create an example for the color illusion. You can choose from:
# + Simultaneous Contrast: Colors look different depending on the surrounding colors (light and dark).
# + Gradient Illusion: how the gradient background affect the solid color in front of it.
# + Color Context Effects: The same color can appear lighter, darker, or even as a different hue depending on its background, eg: the border.
#
# Attach the picture of your design to the homework (You can zip the picture and .ipynb file when you submit it or submit the GitHub repo). You can choose any tool for your design, PPT, Canvas, Photoshop etc. Do not directly copy the lecture examples. Write a few sentence about your design. How you design it and which illusion you are addressing.

# %% [markdown]
# **See illusion.png in zip file**

# %% [markdown]
# This design combines the illusion of simultaneous contrast and brightness illusion. In this image, the same square is placed on a light gray background and a dark gray background. Although the difference is subtle, the square on the dark gray background looks lighter than the square on the lighter background, even though these squares are the same shade of red.
